# %%
#Dataframe manipulation library
import pandas as pd
#Math functions, we'll only need the sqrt function so let's import only that
from math import sqrt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies_df = pd.read_csv("movies.csv")
ratings_df = pd.read_csv("ratings.csv")

# %%
movies_df.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings_df.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      169     2.5  1204927694
# 1       1     2471     3.0  1204927438
# 2       1    48516     5.0  1204927435
# 3       2     2571     3.5  1436165433
# 4       2   109487     4.0  1436165496

# %%
# Make a different column for years in movies_df

#extracting year with parenthesis
movies_df['year'] = movies_df.title.str.extract('(\(\d\d\d\d\))',expand=False)

#remove parenthesis from year column
movies_df['year'] = movies_df.year.str.extract('(\d\d\d\d)', expand=False)

#remove year from title
movies_df['title'] = movies_df.title.str.replace('(\(\d\d\d\d\))', '')

movies_df.head()
# Out:
#    movieId                         title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
# Remove genre column
movies_df = movies_df.drop('genres', 1)
movies_df.head()
# Out:
#    movieId                         title  year
# 0        1                    Toy Story   1995
# 1        2                      Jumanji   1995
# 2        3             Grumpier Old Men   1995
# 3        4            Waiting to Exhale   1995
# 4        5  Father of the Bride Part II   1995

# %%
# Remove timestamp column from ratings_df
ratings_df = ratings_df.drop('timestamp', 1)
ratings_df.head()
# Out:
#    userId  movieId  rating
# 0       1      169     2.5
# 1       1     2471     3.0
# 2       1    48516     5.0
# 3       2     2571     3.5
# 4       2   109487     4.0

# %%
# User input to select data from
userInput = [
            {'title':'Breakfast Club, The', 'rating':5, 'movieId':1968},
            {'title':'Toy Story', 'rating':3.5, 'movieId':1},
            {'title':'Jumanji', 'rating':2, 'movieId':2},
            {'title':"Pulp Fiction", 'rating':5, 'movieId':296},
            {'title':'Akira', 'rating':4.5, 'movieId':1274}
         ]

# %%
# Converting dictionary to DataFrame
userInput_df = pd.DataFrame(userInput)
userInput_df.head(20)
# Out:
#                  title  rating  movieId
# 0  Breakfast Club, The     5.0     1968
# 1            Toy Story     3.5        1
# 2              Jumanji     2.0        2
# 3         Pulp Fiction     5.0      296
# 4                Akira     4.5     1274

# %%
# creating another DataFrame consisting of users that have movies in common with the input user
userSubset_df = ratings_df[ratings_df['movieId'].isin(userInput_df['movieId'].tolist())]

# %%
userSubset_df.head(20)
# Out:
#       userId  movieId  rating
# 19         4      296     4.0
# 441       12     1968     3.0
# 479       13        2     2.0
# 531       13     1274     5.0
# 681       14      296     2.0
# 749       15        1     4.0
# 776       15      296     3.0
# 911       15     1968     3.0
# 1247      17        1     5.0
# 1248      17        2     3.0
# 1333      17      296     2.0
# 1851      17     1968     3.0
# 2283      18      296     4.0
# 2342      20      296     3.0
# 2752      23        1     5.0
# 2981      26     1968     5.0
# 3017      28        1     4.0
# 3266      31      296     4.5
# 3363      32      296     5.0
# 3402      34        1     3.0

# %%
# create several subframes where they all have a common userId in each subframe
userSubsetGroup = userSubset_df.groupby(['userId'])
userSubsetGroup.get_group(75)
# Out:
#       userId  movieId  rating
# 7507      75        1     5.0
# 7508      75        2     3.5
# 7540      75      296     5.0
# 7633      75     1274     4.5
# 7673      75     1968     5.0

# %%
# we can now sequence the subframes in such a way that the subframes with highest count of elements occur first
userSubsetGroup = sorted(userSubsetGroup, key= lambda x: len(x[1]), reverse = True)
userSubsetGroup[:10]
# Out:
# [(75,
#         userId  movieId  rating
#   7507      75        1     5.0
#   7508      75        2     3.5
#   7540      75      296     5.0
#   7633      75     1274     4.5
#   7673      75     1968     5.0),
#  (106,
#         userId  movieId  rating
#   9083     106        1     2.5
#   9084     106        2     3.0
#   9115     106      296     3.5
#   9198     106     1274     3.0
#   9238     106     1968     3.5),
#  (686,
#          userId  movieId  rating
#   61336     686        1     4.0
#   61337     686        2     3.0
#   61377     686      296     4.0
#   61478     686     1274     4.0
#   61569     686     1968     5.0),
#  (815,
#          userId  movieId  rating
#   73747     815        1     4.5
#   73748     815        2     3.0
#   73922     815      296     5.0
#   74362     815     1274     3.0
#   74678     815     1968     4.5),
#  (1040,
#          userId  movieId  rating
#   96689    1040        1     3.0
#   96690    1040        2     1.5
#   96733    1040      296     3.5
#   96859    1040     1274     3.0
#   96922    1040     1968     4.0),
#  (1130,
#           userId  movieId  rating
#   104167    1130        1     0.5
#   104168    1130        2     4.0
#   104214    1130      296     4.0
#   104363    1130     1274     4.5
#   104443    1130     1968     4.5),
#  (1502,
#           userId  movieId  rating
#   133876    1502        1     4.0
#   133877    1502        2     3.5
#   133917    1502      296     5.0
#   134058    1502     1274     4.0
#   134133    1502     1968     5.0),
#  (1599,
#           userId  movieId  rating
#   142722    1599        1     4.0
#   142723    1599        2     4.0
#   142810    1599      296     5.0
#   143068    1599     1274     4.0
#   143220    1599     1968     4.0),
#  (1625,
#           userId  movieId  rating
#   146811    1625        1     4.0
#   146812    1625        2     3.5
#   146867    1625      296     5.0
#   147011    1625     1274     4.0
#   147107    1625     1968     4.0),
#  (1950,
#           userId  movieId  rating
#   176143    1950        1     5.0
#   176144    1950        2     4.0
#   176186    1950      296     5.0
#   176349    1950     1274     4.0
#   176444    1950     1968     4.0)]

# %%
# to reduce complexity in running time, let us limit the userId to top 100 users
userSubsetGroup = userSubsetGroup[0:100]

# %%
# storing userId and similarityIndex of each user in userSubsetGroup in a dictionary
# similarityIndex domain [-1,1]

similarityIndexDict = {}

for name, group in userSubsetGroup:
    #first we need to make sure that the movieId in userInput and each subframe of userSubsetGroup is sorted
    group = group.sort_values('movieId')
    inputMovies = userInput_df.sort_values('movieId')
    
    #next we need to get (nRatings) the number of ratings each subframe and the userInput_df have in common
    nRatings = len(group)
    #since we had just chosen the top 100 subframes, it is very likely that nRatings for all is same(5) but we can't assume it
    
    #Get the review scores for the movies that they both have in common
    temp_df = inputMovies[inputMovies['movieId'].isin(group['movieId'].tolist())]
    
    #Ratings from userInput
    tempRatingList = temp_df['rating'].tolist()
    
    #Each ratings frame from subframe 
    tempGroupList = group['rating'].tolist()
    
    #We can calculate the similarityIndex (Pearson correlation)
    Sxx = sum([i**2 for i in tempRatingList]) - pow(sum(tempRatingList),2)/float(nRatings)
    Syy = sum([i**2 for i in tempGroupList]) - pow(sum(tempGroupList),2)/float(nRatings)
    Sxy = sum( i*j for i, j in zip(tempRatingList, tempGroupList)) - sum(tempRatingList)*sum(tempGroupList)/float(nRatings)
    
    #If the denominator is different than zero, then divide, else, 0 correlation.
    if Sxx != 0 and Syy != 0:
        similarityIndexDict[name] = Sxy/sqrt(Sxx*Syy)
    else:
        similarityIndexDict[name] = 0
    
    
#print(similarityIndexDict)
#temp_df.head(50)
#tempRatingList
#tempGroupList

# %%
similarityIndexDict.items()
# Out:
# dict_items([(75, 0.8272781516947562), (106, 0.5860090386731182), (686, 0.8320502943378437), (815, 0.5765566601970551), (1040, 0.9434563530497265), (1130, 0.2891574659831201), (1502, 0.8770580193070299), (1599, 0.4385290096535153), (1625, 0.716114874039432), (1950, 0.179028718509858), (2065, 0.4385290096535153), (2128, 0.5860090386731196), (2432, 0.1386750490563073), (2791, 0.8770580193070299), (2839, 0.8204126541423674), (2948, -0.11720180773462392), (3025, 0.45124262819713973), (3040, 0.89514359254929), (3186, 0.6784622064861935), (3271, 0.26989594817970664), (3429, 0.0), (3734, -0.15041420939904673), (4099, 0.05860090386731196), (4208, 0.29417420270727607), (4282, -0.4385290096535115), (4292, 0.6564386345361464), (4415, -0.11183835382312353), (4586, -0.9024852563942795), (4725, -0.08006407690254357), (4818, 0.4885967564883424), (5104, 0.7674257668936507), (5165, -0.4385290096535153), (5547, 0.17200522903844556), (6082, -0.04728779924109591), (6207, 0.9615384615384616), (6366, 0.6577935144802716), (6482, 0.0), (6530, -0.3516054232038709), (7235, 0.6981407669689391), (7403, 0.11720180773462363), (7641, 0.7161148740394331), (7996, 0.626600514784504), (8008, -0.22562131409856986), (8086, 0.6933752452815365), (8245, 0.0), (8572, 0.8600261451922278), (8675, 0.5370861555295773), (9101, -0.08600261451922278), (9358, 0.692178738358485), (9663, 0.193972725041952), (9994, 0.5030272728659587), (10248, -0.24806946917841693), (10315, 0.537086155529574), (10368, 0.4688072309384945), (10607, 0.41602514716892186), (10707, 0.9615384615384616), (10863, 0.6020183016345595), (11314, 0.8204126541423654), (11399, 0.517260600111872), (11769, 0.9376144618769914), (11827, 0.4902903378454601), (12069, 0.0), (12120, 0.9292940047327363), (12211, 0.8600261451922278), (12325, 0.9616783115081544), (12916, 0.5860090386731196), (12921, 0.6611073566849309), (13053, 0.9607689228305227), (13142, 0.6016568375961863), (13260, 0.7844645405527362), (13366, 0.8951435925492911), (13768, 0.8770580193070289), (13888, 0.2508726030021272), (13923, 0.3516054232038718), (13934, 0.17200522903844556), (14529, 0.7417901772340937), (14551, 0.537086155529574), (14588, 0.21926450482675766), (14984, 0.716114874039432), (15137, 0.5860090386731196), (15157, 0.9035841064985974), (15466, 0.7205766921228921), (15670, 0.516015687115336), (15834, 0.22562131409856986), (16292, 0.6577935144802716), (16456, 0.7161148740394331), (16506, 0.5481612620668942), (17246, 0.48038446141526137), (17438, 0.7093169886164387), (17501, 0.8168748513121271), (17502, 0.8272781516947562), (17666, 0.7689238340176859), (17735, 0.7042381820123422), (17742, 0.3922322702763681), (17757, 0.64657575013984), (17854, 0.537086155529574), (17897, 0.8770580193070289), (17944, 0.2713848825944774), (18301, 0.29838119751643016), (18509, 0.1322214713369862)])

# %%
# creating a similarity_df from the similarityIndexDict with keys being userId and values being similarityIndex
similarity_df = pd.DataFrame(similarityIndexDict.keys())
similarity_df.columns = ['userId']
similarity_df['similarityIndex'] = similarityIndexDict.values()

# %%
# only 100
similarity_df.head(200)
# Out:
#     userId  similarityIndex
# 0       75         0.827278
# 1      106         0.586009
# 2      686         0.832050
# 3      815         0.576557
# 4     1040         0.943456
# ..     ...              ...
# 95   17854         0.537086
# 96   17897         0.877058
# 97   17944         0.271385
# 98   18301         0.298381
# 99   18509         0.132221
#
# [100 rows x 2 columns]

# %%
# making it in descending order of similarityIndex
similarity_df = similarity_df.sort_values(by = 'similarityIndex', ascending = False)[0:50]

# %%
similarity_df.head(50)
# Out:
#     userId  similarityIndex
# 64   12325         0.961678
# 34    6207         0.961538
# 55   10707         0.961538
# 67   13053         0.960769
# 4     1040         0.943456
# 59   11769         0.937614
# 62   12120         0.929294
# 80   15157         0.903584
# 70   13366         0.895144
# 17    3040         0.895144
# 6     1502         0.877058
# 13    2791         0.877058
# 71   13768         0.877058
# 96   17897         0.877058
# 63   12211         0.860026
# 45    8572         0.860026
# 2      686         0.832050
# 90   17502         0.827278
# 0       75         0.827278
# 14    2839         0.820413
# 57   11314         0.820413
# 89   17501         0.816875
# 69   13260         0.784465
# 91   17666         0.768924
# 30    5104         0.767426
# 75   14529         0.741790
# 81   15466         0.720577
# 85   16456         0.716115
# 40    7641         0.716115
# 78   14984         0.716115
# 8     1625         0.716115
# 88   17438         0.709317
# 92   17735         0.704238
# 38    7235         0.698141
# 43    8086         0.693375
# 48    9358         0.692179
# 18    3186         0.678462
# 66   12921         0.661107
# 84   16292         0.657794
# 35    6366         0.657794
# 25    4292         0.656439
# 94   17757         0.646576
# 41    7996         0.626601
# 56   10863         0.602018
# 68   13142         0.601657
# 65   12916         0.586009
# 11    2128         0.586009
# 79   15137         0.586009
# 1      106         0.586009
# 3      815         0.576557

# %%
# merging movieId and rating provided by each userId
similarity_df = similarity_df.merge(ratings_df, left_on = 'userId', right_on = 'userId', how = 'inner')

# %%
similarity_df.head(2000)
# Out:
#       userId  similarityIndex  movieId  rating
# 0      12325         0.961678        1     3.5
# 1      12325         0.961678        2     1.5
# 2      12325         0.961678        3     3.0
# 3      12325         0.961678        5     0.5
# 4      12325         0.961678        6     2.5
# ...      ...              ...      ...     ...
# 1995   13053         0.960769      293     4.0
# 1996   13053         0.960769      296     4.5
# 1997   13053         0.960769      306     4.5
# 1998   13053         0.960769      307     4.5
# 1999   13053         0.960769      308     3.0
#
# [2000 rows x 4 columns]

# %%
# making another column weightedRating = rating*similarityIndex
similarity_df['weightedRating'] = similarity_df['similarityIndex'] * similarity_df['rating']

# %%
similarity_df.head(2000)
# Out:
#       userId  similarityIndex  movieId  rating  weightedRating
# 0      12325         0.961678        1     3.5        3.365874
# 1      12325         0.961678        2     1.5        1.442517
# 2      12325         0.961678        3     3.0        2.885035
# 3      12325         0.961678        5     0.5        0.480839
# 4      12325         0.961678        6     2.5        2.404196
# ...      ...              ...      ...     ...             ...
# 1995   13053         0.960769      293     4.0        3.843076
# 1996   13053         0.960769      296     4.5        4.323460
# 1997   13053         0.960769      306     4.5        4.323460
# 1998   13053         0.960769      307     4.5        4.323460
# 1999   13053         0.960769      308     3.0        2.882307
#
# [2000 rows x 5 columns]

# %%
# calculating sum of similarityIndex and weightedRating and creating columns for it
similarity_df = similarity_df.groupby('movieId').sum()[['similarityIndex','weightedRating']]
similarity_df.columns = ['sum_similarityIndex','sum_weightedRating']

# %%
similarity_df.head(2000)
# Out:
#          sum_similarityIndex  sum_weightedRating
# movieId
# 1                  38.376281          140.800834
# 2                  38.376281           96.656745
# 3                  10.253981           27.254477
# 4                   0.929294            2.787882
# 5                  11.723262           27.151751
# ...                      ...                 ...
# 2925                1.479076            6.518324
# 2926                4.618765           15.629836
# 2927                1.904142            8.804596
# 2928                0.767426            1.534852
# 2932                0.816875            2.450625
#
# [2000 rows x 2 columns]

# %%
# creating 'weighted average recommendation score' column
similarity_df['weighted average recommendation score'] = similarity_df['sum_weightedRating']/similarity_df['sum_similarityIndex']
similarity_df = similarity_df.drop(['sum_similarityIndex', 'sum_weightedRating'], 1)

# %%
similarity_df.head(2000)
# Out:
#          weighted average recommendation score
# movieId
# 1                                     3.668955
# 2                                     2.518658
# 3                                     2.657941
# 4                                     3.000000
# 5                                     2.316058
# ...                                        ...
# 2925                                  4.407023
# 2926                                  3.383986
# 2927                                  4.623917
# 2928                                  2.000000
# 2932                                  3.000000
#
# [2000 rows x 1 columns]

# %%
# merging similarity_df and movies_df
movies_df = movies_df.merge(similarity_df, left_on='movieId', right_on='movieId', how='inner')

# %%
movies_df.head(200)
# Out:
#      movieId                                              title  year  \
# 0          1                                         Toy Story   1995
# 1          2                                           Jumanji   1995
# 2          3                                  Grumpier Old Men   1995
# 3          4                                 Waiting to Exhale   1995
# 4          5                       Father of the Bride Part II   1995
# ..       ...                                                ...   ...
# 195      251                                       Hunted, The   1995
# 196      252                                              I.Q.   1994
# 197      253  Interview with the Vampire: The Vampire Chroni...  1994
# 198      254                                Jefferson in Paris   1995
# 199      255                                   Jerky Boys, The   1995
#
#      weighted average recommendation score
# 0                                 3.668955
# 1                                 2.518658
# 2                                 2.657941
# 3                                 3.000000
# 4                                 2.316058
# ..                                     ...
# 195                               2.633109
# 196                               2.909530
# 197                               3.815204
# 198                               2.000000
# 199                               1.578583
#
# [200 rows x 4 columns]

# %%
# sorting 'weighted average recommendation score' in decending order to get the movies with highest average recommendation score
movies_df = movies_df.sort_values(by='weighted average recommendation score', ascending=False)

# %%
movies_df.head(60)
# Out:
#       movieId                                              title  year  \
# 3364     5073           Son's Room, The (Stanza del figlio, La)   2001
# 2241     3329                          Year My Voice Broke, The   1987
# 1543     2284                                      Bandit Queen   1994
# 4962    26801               Dragon Inn (Sun lung moon hak chan)   1992
# 4122     6776                 Lagaan: Once Upon a Time in India   2001
# 4076     6672                                  War Photographer   2001
# 2505     3759                                Fun and Fancy Free   1947
# 2514     3769                         Thunderbolt and Lightfoot   1974
# 2519     3775                                   Make Mine Music   1946
# 7087    90531                                             Shame   2011
# 2520     3776                                       Melody Time   1948
# 2367     3539                           Filth and the Fury, The   2000
# 2565     3851                           I'm the One That I Want   2000
# 95        121                          Boys of St. Vincent, The   1992
# 4073     6668              Road Home, The (Wo de fu qin mu qin)   1999
# 4069     6660                                    Red Shoes, The   1948
# 4184     6918                     Unvanquished, The (Aparajito)   1957
# 80         99                     Heidi Fleiss: Hollywood Madam   1995
# 4267     7043  Vivre sa vie: Film en douze tableaux (My Life ...  1962
# 7108    91199                                           Weekend   2011
# 4299     7122                                    King of Hearts   1966
# 4341     7209  M. Hulot’s Holiday (Mr. Hulot's Holiday) (Vaca...  1953
# 2321     3470                                       Dersu Uzala   1975
# 1151     1695                                         Artemisia   1997
# 2310     3451                      Guess Who's Coming to Dinner   1967
# 7788   111441        Lady in Number 6: Music Saved My Life, The   2014
# 4539     7983                               Broadway Danny Rose   1984
# 7799   112006                                Tangled Ever After   2012
# 1491     2182                                    Wrong Man, The   1956
# 1077     1596                                      Career Girls   1997
# 6632    73587                                      Soul Kitchen   2009
# 1258     1902                            Dream for an Insomniac   1996
# 3968     6433  Man with the Movie Camera, The (Chelovek s kin...  1929
# 4042     6611                                        Umberto D.   1952
# 2279     3406                   Captain Horatio Hornblower R.N.   1951
# 3174     4766  Our Lady of the Assassins (Virgen de los sicar...  2000
# 7368   100106                  Pervert's Guide to Ideology, The   2012
# 7360    99917                                    Upstream Color   2013
# 7332    98981                           Arrival of a Train, The   1896
# 3330     5022                                      Servant, The   1963
# 3332     5024                        Come Undone (Presque Rien)   2000
# 2903     4356                          Gentlemen Prefer Blondes   1953
# 2896     4347               Divided We Fall (Musíme si pomáhat)   2000
# 2885     4334                                             Yi Yi   2000
# 2845     4252                             Circle, The (Dayereh)   2000
# 7312    98056                                             Amour   2012
# 7615   106109           Masquerade (Gwanghai, Wangyidoen namja)   2012
# 3387     5121                                          Stroszek   1977
# 7652   106762                           Trigun: Badlands Rumble   2010
# 3430     5244                                   Shogun Assassin   1980
# 7272    96868                         Shut Up and Play the Hits   2012
# 1374     2041                                         Condorman   1981
# 7239    96062                                            Jekyll   2007
# 7236    95939                                Angels' Share, The   2012
# 3714     5817                                            Ararat   2002
# 2780     4160  Widow of St. Pierre, The (Veuve de Saint-Pierr...  2000
# 207       263                                 Ladybird Ladybird   1994
# 2697     4038                                     Kill Me Again   1989
# 1601     2362                                    Glen or Glenda   1953
# 3900     6291                       Lilya 4-Ever (Lilja 4-ever)   2002
#
#       weighted average recommendation score
# 3364                                    5.0
# 2241                                    5.0
# 1543                                    5.0
# 4962                                    5.0
# 4122                                    5.0
# 4076                                    5.0
# 2505                                    5.0
# 2514                                    5.0
# 2519                                    5.0
# 7087                                    5.0
# 2520                                    5.0
# 2367                                    5.0
# 2565                                    5.0
# 95                                      5.0
# 4073                                    5.0
# 4069                                    5.0
# 4184                                    5.0
# 80                                      5.0
# 4267                                    5.0
# 7108                                    5.0
# 4299                                    5.0
# 4341                                    5.0
# 2321                                    5.0
# 1151                                    5.0
# 2310                                    5.0
# 7788                                    5.0
# 4539                                    5.0
# 7799                                    5.0
# 1491                                    5.0
# 1077                                    5.0
# 6632                                    5.0
# 1258                                    5.0
# 3968                                    5.0
# 4042                                    5.0
# 2279                                    5.0
# 3174                                    5.0
# 7368                                    5.0
# 7360                                    5.0
# 7332                                    5.0
# 3330                                    5.0
# 3332                                    5.0
# 2903                                    5.0
# 2896                                    5.0
# 2885                                    5.0
# 2845                                    5.0
# 7312                                    5.0
# 7615                                    5.0
# 3387                                    5.0
# 7652                                    5.0
# 3430                                    5.0
# 7272                                    5.0
# 1374                                    5.0
# 7239                                    5.0
# 7236                                    5.0
# 3714                                    5.0
# 2780                                    5.0
# 207                                     5.0
# 2697                                    5.0
# 1601                                    5.0
# 3900                                    5.0

# %%
# Thus the weighted average score with 5 gives the movies with top user-user collaborative recommendation engine
# These are the top movies which Netflix abreviates as "People who watched this also liked"......
